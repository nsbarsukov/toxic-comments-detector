# %% [markdown]
# <div style="display: flex;">
#     <a href="https://t.me/nsbarsukov" style="margin-right:20px;">
#         <img src="https://img.shields.io/badge/Telegram-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="write-me-telegram"/>
#     </a>
#     <a href="https://github.com/nsbarsukov/toxic-comments-detector" style="margin-right:20px;">
#         <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" alt="Open Github"/>
#     </a>
# </div>
# <div style="display: flex; margin-top: 20px;">
#     <a href="https://colab.research.google.com/github/nsbarsukov/toxic-comments-detector/blob/master/models/05weightedCNN%2BNavec.ipynb">
#         <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#     </a>
# </div>

# %%
import os

def check_is_google_colab():
    return 'google.colab' in str(get_ipython())


def prepare_environment():
    if check_is_google_colab():
        from google.colab import drive
        import shutil
        
        drive.mount('/content/gdrive/')

        PATH_TO_TEMP_REPO = '/content/gdrive/My Drive/toxic-comments-repo-temp'

        try:
            shutil.rmtree(PATH_TO_TEMP_REPO)
        except:
            pass

        os.mkdir(PATH_TO_TEMP_REPO)
        
        # %cd ./gdrive/My Drive/toxic-comments-repo-temp
        ! git clone https://github.com/nsbarsukov/toxic-comments-detector.git .
        ! pip3 install -q tensorflow_text navec
    else:
        # %cd ..

prepare_environment()
# Out:
# /Users/n.barsukov/PycharmProjects/toxic-comments-detector

# %%
import sys
import tensorflow as tf
import numpy as np

# local (this repo) imports
from dev import (
    load_cleaned_russian_text_data,
    get_class_weights,
    get_initial_output_bias,
    evaluate_model,
    make_sentence_vectorizer,
    get_3d_quartile_words_count,
    SEED,
    VALIDATION_SPLIT_PARTITION,
    DEFAULT_BATCH_SIZE,
    DEFAULT_EPOCHS,
)
from wordEmbeddingsLayers import get_navec_word_vectorizer

tf.random.set_seed(SEED)

print('Python version:', sys.version)
print('Tensorflow version:', tf.__version__)
# Out:
# Python version: 3.8.9 (default, Apr  3 2021, 01:50:09)
# [Clang 12.0.0 (clang-1200.0.32.29)]
# Tensorflow version: 2.4.1

# %% [markdown]
# # Word Vectorizer

# %%
X_train, X_test, y_train, y_test = load_cleaned_russian_text_data()

# %%
VECTORIZED_SENTENCE_LENGTH = get_3d_quartile_words_count(X_train.flatten())

navec_word_vectorizer, NAVEC_EMBEDDING_DIMENSION = get_navec_word_vectorizer()

navec_sentence_vectorizer = make_sentence_vectorizer(
    vectorizer=navec_word_vectorizer,
    pad_sentence_to_n_words=VECTORIZED_SENTENCE_LENGTH
)

# %%
X_train = np.array(list(
    map(navec_sentence_vectorizer, X_train.flatten())
))

X_test = np.array(list(
    map(navec_sentence_vectorizer, X_test.flatten())
))

# %% [markdown]
# # Build CNN model

# %%
from tensorflow.keras import layers, losses

negative_class_amount, pos_class_amount = np.bincount(y_train)

initial_output_bias = tf.keras.initializers.Constant(
    get_initial_output_bias(pos_class_amount, negative_class_amount)
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=2,
    verbose=1,
    restore_best_weights=False
)

model = tf.keras.Sequential([
    layers.Input(shape=(VECTORIZED_SENTENCE_LENGTH, NAVEC_EMBEDDING_DIMENSION,), dtype=tf.float32),
    
    layers.Conv1D(filters=128, kernel_size=5, activation='relu'),
    layers.GlobalMaxPool1D(),
    
    layers.Dense(units=128, activation='relu'),
    layers.Dropout(rate=0.5, seed=SEED),
    layers.Dense(
        units=1,
        bias_initializer=initial_output_bias
    ),
    layers.Activation('sigmoid') # то есть в конце мы выдаем уже вероятности
])

model.compile(
    loss=losses.BinaryCrossentropy(from_logits=False), # from_logits=False, т.к. на выходе layers.Activation('sigmoid')
    optimizer='adam',
    metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    epochs=DEFAULT_EPOCHS,
    batch_size=DEFAULT_BATCH_SIZE,
    validation_split=VALIDATION_SPLIT_PARTITION,
    callbacks=[early_stopping],
    class_weight=get_class_weights(pos_class_amount, negative_class_amount),
)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 10s 331ms/step - loss: 0.6439 - binary_accuracy: 0.6565 - recall: 0.5541 - precision: 0.5019 - val_loss: 0.3700 - val_binary_accuracy: 0.8504 - val_recall: 0.7917 - val_precision: 0.7667
# Epoch 2/10
# 19/19 [==============================] - 3s 128ms/step - loss: 0.3760 - binary_accuracy: 0.8556 - recall: 0.8097 - precision: 0.7747 - val_loss: 0.3735 - val_binary_accuracy: 0.8543 - val_recall: 0.8685 - val_precision: 0.7395
# Epoch 3/10
# 19/19 [==============================] - 3s 150ms/step - loss: 0.3045 - binary_accuracy: 0.8855 - recall: 0.8832 - precision: 0.7972 - val_loss: 0.3506 - val_binary_accuracy: 0.8686 - val_recall: 0.8750 - val_precision: 0.7645
# Epoch 4/10
# 19/19 [==============================] - 3s 134ms/step - loss: 0.2824 - binary_accuracy: 0.8894 - recall: 0.9150 - precision: 0.7934 - val_loss: 0.3066 - val_binary_accuracy: 0.8751 - val_recall: 0.7773 - val_precision: 0.8361
# Epoch 5/10
# 19/19 [==============================] - 3s 135ms/step - loss: 0.2534 - binary_accuracy: 0.9069 - recall: 0.8738 - precision: 0.8531 - val_loss: 0.4566 - val_binary_accuracy: 0.8196 - val_recall: 0.9414 - val_precision: 0.6609
# Epoch 6/10
# 19/19 [==============================] - 3s 138ms/step - loss: 0.2457 - binary_accuracy: 0.8936 - recall: 0.9381 - precision: 0.7903 - val_loss: 0.3020 - val_binary_accuracy: 0.8803 - val_recall: 0.7969 - val_precision: 0.8361
# Epoch 7/10
# 19/19 [==============================] - 2s 106ms/step - loss: 0.2014 - binary_accuracy: 0.9332 - recall: 0.9158 - precision: 0.8909 - val_loss: 0.3687 - val_binary_accuracy: 0.8634 - val_recall: 0.8958 - val_precision: 0.7454
# Epoch 8/10
# 19/19 [==============================] - 2s 82ms/step - loss: 0.1642 - binary_accuracy: 0.9407 - recall: 0.9609 - precision: 0.8768 - val_loss: 0.3198 - val_binary_accuracy: 0.8825 - val_recall: 0.8398 - val_precision: 0.8134
# Epoch 00008: early stopping

# %% [markdown]
# # Model evaluation

# %%
y_test_pred = (model.predict(X_test).flatten() > 0.5) * 1

evaluate_model(y_test, y_test_pred, history)
# Out:
# Accuracy: 90.67%
# Recall: 88.68%
# Precision: 84.01%
# F1-score: 86.28%
