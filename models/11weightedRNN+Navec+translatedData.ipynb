# %% [markdown]
# <div style="display: flex;">
#     <a href="https://t.me/nsbarsukov" style="margin-right:20px;">
#         <img src="https://img.shields.io/badge/Telegram-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="write-me-telegram"/>
#     </a>
#     <a href="https://github.com/nsbarsukov/toxic-comments-detector" style="margin-right:20px;">
#         <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" alt="Open Github"/>
#     </a>
# </div>
# <div style="display: flex; margin-top: 20px;">
#     <a href="https://colab.research.google.com/github/nsbarsukov/toxic-comments-detector/blob/master/models/05weightedCNN%2BNavec.ipynb">
#         <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#     </a>
# </div>

# %%
MODEL_NAME = 'weightedRNN_NavecWordEmbeddings_translatedData'

# %%
import os

def check_is_google_colab():
    return 'google.colab' in str(get_ipython())


def prepare_environment():
    if check_is_google_colab():
        from google.colab import drive
        import shutil
        
        drive.mount('/content/gdrive/')

        PATH_TO_TEMP_REPO = '/content/gdrive/My Drive/toxic-comments-repo-temp'

        try:
            shutil.rmtree(PATH_TO_TEMP_REPO)
        except:
            pass

        os.mkdir(PATH_TO_TEMP_REPO)
        
        # %cd ./gdrive/My Drive/toxic-comments-repo-temp
        ! git clone https://github.com/nsbarsukov/toxic-comments-detector.git .
        ! pip3 install -q tensorflow_text navec
    else:
        # %cd ..

prepare_environment()
# Out:
# /Users/n.barsukov/PycharmProjects/toxic-comments-detector

# %%
import sys
import tensorflow as tf
import numpy as np

# local (this repo) imports
from dev import (
    load_cleaned_russian_text_data,
    load_translated_from_english_cleaned_russian_text_data,
    get_class_weights,
    evaluate_model,
    show_tf_model_summary,
    make_sentence_vectorizer,
    get_3d_quartile_words_count,
    early_stopping_cb,
    save_tf_model,
    SEED,
    VALIDATION_SPLIT_PARTITION,
    DEFAULT_BATCH_SIZE,
    DEFAULT_EPOCHS,
)
from wordEmbeddingsLayers import get_navec_word_vectorizer

tf.random.set_seed(SEED)

print('Python version:', sys.version)
print('Tensorflow version:', tf.__version__)
# Out:
# Python version: 3.8.9 (default, Apr  3 2021, 01:50:09)
# [Clang 12.0.0 (clang-1200.0.32.29)]
# Tensorflow version: 2.4.1

# %% [markdown]
# # Word Vectorizer

# %%
X_translated_pretrain, y_translated_pretrain = load_translated_from_english_cleaned_russian_text_data()
X_train, X_test, y_train, y_test = load_cleaned_russian_text_data()

# %%
VECTORIZED_SENTENCE_LENGTH = get_3d_quartile_words_count(X_train.flatten())

navec_word_vectorizer, NAVEC_EMBEDDING_DIMENSION = get_navec_word_vectorizer()

navec_sentence_vectorizer = make_sentence_vectorizer(
    vectorizer=navec_word_vectorizer,
    pad_sentence_to_n_words=VECTORIZED_SENTENCE_LENGTH
)

# %%
X_translated_pretrain = np.array(list(
    map(navec_sentence_vectorizer, X_translated_pretrain.flatten())
))

X_train = np.array(list(
    map(navec_sentence_vectorizer, X_train.flatten())
))

X_test = np.array(list(
    map(navec_sentence_vectorizer, X_test.flatten())
))

# %% [markdown]
# # Build CNN model

# %%
from tensorflow.keras import layers, losses

model = tf.keras.Sequential([
    layers.Input(
        shape=(VECTORIZED_SENTENCE_LENGTH, NAVEC_EMBEDDING_DIMENSION,),
        dtype=tf.float32,
        name='Navec_word_embeddings'
    ),
    
    layers.Bidirectional(layers.LSTM(256), name='biLSTM'),
    
    layers.Dense(units=128, activation='relu', name='FC_Layer_Relu'),
    layers.Dropout(rate=0.5, seed=SEED, name='Regularization'),
    layers.Dense(
        units=1,
        name='FC_Layer_sigmoid',
        activation='sigmoid'
    ),
], name=MODEL_NAME)

model.compile(
    loss=losses.BinaryCrossentropy(from_logits=False), # from_logits=False, т.к. на выходе activation='sigmoid'
    optimizer='adam',
    metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

# %%
pretrain_history = model.fit(
    x=X_translated_pretrain,
    y=y_translated_pretrain,
    epochs=DEFAULT_EPOCHS,
    batch_size=DEFAULT_BATCH_SIZE,
    validation_split=VALIDATION_SPLIT_PARTITION,
    callbacks=[early_stopping_cb],
)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 14s 532ms/step - loss: 0.6254 - binary_accuracy: 0.6405 - recall: 0.5530 - precision: 0.6546 - val_loss: 0.4887 - val_binary_accuracy: 0.7665 - val_recall: 0.7156 - val_precision: 0.7888
# Epoch 2/10
# 16/16 [==============================] - 8s 489ms/step - loss: 0.4778 - binary_accuracy: 0.7752 - recall: 0.7577 - precision: 0.7846 - val_loss: 0.4506 - val_binary_accuracy: 0.7860 - val_recall: 0.7176 - val_precision: 0.8234
# Epoch 3/10
# 16/16 [==============================] - 8s 521ms/step - loss: 0.4481 - binary_accuracy: 0.7927 - recall: 0.7805 - precision: 0.8012 - val_loss: 0.4476 - val_binary_accuracy: 0.7920 - val_recall: 0.7054 - val_precision: 0.8449
# Epoch 4/10
# 16/16 [==============================] - 8s 509ms/step - loss: 0.4172 - binary_accuracy: 0.8083 - recall: 0.8094 - precision: 0.8110 - val_loss: 0.4200 - val_binary_accuracy: 0.8070 - val_recall: 0.7727 - val_precision: 0.8230
# Epoch 5/10
# 16/16 [==============================] - 8s 504ms/step - loss: 0.3814 - binary_accuracy: 0.8304 - recall: 0.8129 - precision: 0.8448 - val_loss: 0.4425 - val_binary_accuracy: 0.7880 - val_recall: 0.6769 - val_precision: 0.8612
# Epoch 6/10
# 16/16 [==============================] - 8s 502ms/step - loss: 0.3878 - binary_accuracy: 0.8247 - recall: 0.8063 - precision: 0.8414 - val_loss: 0.4763 - val_binary_accuracy: 0.7915 - val_recall: 0.8614 - val_precision: 0.7504
# Epoch 7/10
# 16/16 [==============================] - 9s 546ms/step - loss: 0.3397 - binary_accuracy: 0.8507 - recall: 0.8513 - precision: 0.8520 - val_loss: 0.4245 - val_binary_accuracy: 0.8075 - val_recall: 0.7808 - val_precision: 0.8184
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping

# %%
negative_class_amount, pos_class_amount = np.bincount(y_train)

history = model.fit(
    x=X_train,
    y=y_train,
    epochs=DEFAULT_EPOCHS,
    batch_size=DEFAULT_BATCH_SIZE,
    validation_split=VALIDATION_SPLIT_PARTITION,
    callbacks=[early_stopping_cb],
    class_weight=get_class_weights(pos_class_amount, negative_class_amount),
)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 13s 550ms/step - loss: 0.4011 - binary_accuracy: 0.8349 - recall: 0.8077 - precision: 0.7303 - val_loss: 0.3096 - val_binary_accuracy: 0.8773 - val_recall: 0.7812 - val_precision: 0.8392
# Epoch 2/10
# 19/19 [==============================] - 10s 553ms/step - loss: 0.3101 - binary_accuracy: 0.8778 - recall: 0.8708 - precision: 0.7883 - val_loss: 0.3063 - val_binary_accuracy: 0.8799 - val_recall: 0.8867 - val_precision: 0.7819
# Epoch 3/10
# 19/19 [==============================] - 11s 581ms/step - loss: 0.2657 - binary_accuracy: 0.8921 - recall: 0.9037 - precision: 0.8012 - val_loss: 0.3812 - val_binary_accuracy: 0.8222 - val_recall: 0.9401 - val_precision: 0.6648
# Epoch 4/10
# 19/19 [==============================] - 11s 564ms/step - loss: 0.2835 - binary_accuracy: 0.8781 - recall: 0.9075 - precision: 0.7709 - val_loss: 0.3404 - val_binary_accuracy: 0.8825 - val_recall: 0.8659 - val_precision: 0.7983
# Epoch 5/10
# 19/19 [==============================] - 11s 576ms/step - loss: 0.2482 - binary_accuracy: 0.9019 - recall: 0.9095 - precision: 0.8190 - val_loss: 0.4468 - val_binary_accuracy: 0.8088 - val_recall: 0.9544 - val_precision: 0.6435
# Restoring model weights from the end of the best epoch.
# Epoch 00005: early stopping

# %% [markdown]
# # Model evaluation

# %%
y_test_pred = (model.predict(X_test).flatten() > 0.5) * 1

evaluate_model(y_test, y_test_pred, tf_history_learning=history, model_name=MODEL_NAME)
# Out:
# Accuracy: 89.84%
# Recall: 91.4%
# Precision: 80.52%
# F1-score: 85.62%

# %%
show_tf_model_summary(model)
# Out:
# Model: "weightedRNN_NavecWordEmbeddings_translatedData"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# biLSTM (Bidirectional)       (None, 512)               1140736
# _________________________________________________________________
# FC_Layer_Relu (Dense)        (None, 128)               65664
# _________________________________________________________________
# Regularization (Dropout)     (None, 128)               0
# _________________________________________________________________
# FC_Layer_sigmoid (Dense)     (None, 1)                 129
# =================================================================
# Total params: 1,206,529
# Trainable params: 1,206,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_tf_model(model)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .savedModels/weightedRNN_NavecWordEmbeddings_translatedData/assets
# INFO:tensorflow:Assets written to: .savedModels/weightedRNN_NavecWordEmbeddings_translatedData/assets

# %%
from dev import DIRECTORY_WITH_SAVED_MODELS
from textPreprocessing import preprocess_text

loaded_model = tf.keras.models.load_model(f'{DIRECTORY_WITH_SAVED_MODELS}/{model.name}')

raw_texts = ['ты чего берега попутал?', 'это правый берег реки, не путай с левым']
preprocessed_texts = np.array(
    list(map(lambda text: navec_sentence_vectorizer(preprocess_text(text)), raw_texts))
)

loaded_model.predict(preprocessed_texts)
# Out:
# array([[0.93047607],
#        [0.5127122 ]], dtype=float32)
